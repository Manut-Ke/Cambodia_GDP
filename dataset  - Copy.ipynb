# %%
import matplotlib.pyplot as plt

fig ,axes = plt.subplots(2,2,figsize=(12,5))

df1 = ['Male', 'Female']
df2 = ['member of professional association', 'other']
df3 = ['worked full-time', 'part time']
df4 = ['work in print', 'on television', 'on radio' ,'online']
size4 = [50,23,17,16]
size3 = [80,20]
size2 = [47,53]
size1= [57,43]

axes[0,0].pie(size1, labels = df1, autopct='%1.1f%%',startangle=90)
axes[0,0].set_title("Journalists")

axes[0,1].pie(size2, labels = df2,  autopct='%1.1f%%', startangle = 90)
axes[0,1].set_title("Membership")

axes[1,0].pie(size4, labels = df4,  autopct='%1.1f%%', startangle = 90)
axes[1,0].set_title("Working place")

axes[1,1].pie(size3, labels = df3,  autopct='%1.1f%%', startangle = 90)
axes[1,1].set_title("Working Time")

plt.show()

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import kurtosis
from scipy.stats import skew

# %%
import pandas as pd

# Load the CSV file
data = pd.read_excel('cambodia_gdp.xlsx', usecols='A, B')

data = data.iloc[0:49]

# Display the first few rows of data
print(data)
# Out:
#     Year  GDP(Million)
# 0   1975    749.129000
# 1   1976    790.357000
# 2   1977    716.261765
# 3   1978    766.642356
# 4   1979    723.738503
# 5   1980    744.384130
# 6   1981    815.153652
# 7   1982    865.516040
# 8   1983    939.291262
# 9   1984   1020.000000
# 10  1985   1100.000000
# 11  1986   1170.000000
# 12  1987   1040.000000
# 13  1988   1660.000000
# 14  1989   1350.000000
# 15  1990   1400.000000
# 16  1991   2050.000000
# 17  1992   2490.000000
# 18  1993   2530.000000
# 19  1994   2790.000000
# 20  1995   3440.000000
# 21  1996   3510.000000
# 22  1997   3440.000000
# 23  1998   3120.000000
# 24  1999   3520.000000
# 25  2000   3650.000000
# 26  2001   3980.000000
# 27  2002   4280.000000
# 28  2003   4660.000000
# 29  2004   5340.000000
# 30  2005   6290.000000
# 31  2006   7270.000000
# 32  2007   8640.000000
# 33  2008  10350.000000
# 34  2009  10400.000000
# 35  2010  11240.000000
# 36  2011  12830.000000
# 37  2012  14050.000000
# 38  2013  15230.000000
# ...

# %%
years= pd.Series([1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023])
GPA_Million=pd.Series( ['$749.13','$790.36','$716.26','$766.64',' $723.74','$744.38','$815.15',' $865.52','$939.29','$1,020.00','$1,100.00','$1,170.00',' $1,040.00','$1,660.00','$1,350.00','$1,400.00','$2,050.00','$2,490.00','$2,530.00','$2,790.00','$3,440.00','$3,510.00','$3,440.00','$3,120.00','$3,520.00','$3,650.00','$3,980.00','$4,280.00','$4,660.00','$5,340.00','$6,290.00','$7,270.00','$8,640.00','$10,350.00','$10,400.00','$11,240.00','$12,830.00','$14,050.00','$15,230.00','$16,700.00','$18,050.00','$20,020.00','$22,180.00','$24,570.00','$27,090.00','$25,870.00','$26,960.00','$29,500.00 ','$31,770.00'])
states=pd.DataFrame({'years': years, 'GPA_Million': GPA_Million})
states
# Out:
#     years  GPA_Million
# 0    1975      $749.13
# 1    1976      $790.36
# 2    1977      $716.26
# 3    1978      $766.64
# 4    1979      $723.74
# 5    1980      $744.38
# 6    1981      $815.15
# 7    1982      $865.52
# 8    1983      $939.29
# 9    1984    $1,020.00
# 10   1985    $1,100.00
# 11   1986    $1,170.00
# 12   1987    $1,040.00
# 13   1988    $1,660.00
# 14   1989    $1,350.00
# 15   1990    $1,400.00
# 16   1991    $2,050.00
# 17   1992    $2,490.00
# 18   1993    $2,530.00
# 19   1994    $2,790.00
# 20   1995    $3,440.00
# 21   1996    $3,510.00
# 22   1997    $3,440.00
# 23   1998    $3,120.00
# 24   1999    $3,520.00
# 25   2000    $3,650.00
# 26   2001    $3,980.00
# 27   2002    $4,280.00
# 28   2003    $4,660.00
# 29   2004    $5,340.00
# 30   2005    $6,290.00
# 31   2006    $7,270.00
# 32   2007    $8,640.00
# 33   2008   $10,350.00
# 34   2009   $10,400.00
# 35   2010   $11,240.00
# 36   2011   $12,830.00
# 37   2012   $14,050.00
# 38   2013   $15,230.00
# ...

# %%
#create visualization of GDP

import matplotlib.pyplot as plt
# data = pd.read_excel('cambodia_gdp.xlsx')
x = list(range(1975,2024))

y = ['$749.13','$790.36','$716.26','$766.64',' $723.74','$744.38','$815.15',' $865.52','$939.29','$1,020.00','$1,100.00',
     '$1,170.00',' $1,040.00','$1,660.00','$1,350.00','$1,400.00','$2,050.00','$2,490.00','$2,530.00','$2,790.00','$3,440.00',
     '$3,510.00','$3,440.00','$3,120.00','$3,520.00','$3,650.00','$3,980.00','$4,280.00','$4,660.00','$5,340.00','$6,290.00',
     '$7,270.00','$8,640.00','$10,350.00','$10,400.00','$11,240.00','$12,830.00','$14,050.00','$15,230.00','$16,700.00',
     '$18,050.00','$20,020.00','$22,180.00','$24,570.00','$27,090.00','$25,870.00','$26,960.00','$29,500.00 ','$31,770.00']
# x = data['GPA_Million']
# y = data['years']
y1 = [float(value.strip().strip('$').replace(',','')) for value in y]
plt.figure(figsize=(12,6))
plt.plot(x,y1,marker='o', linestyle='-', color='b', label="GPA in Million $")
plt.title("GDP in Cambodia",fontsize = 14)
plt.xlabel('Year', fontsize = 12)
plt.ylabel('GDP Million', fontsize = 12)
# plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

#use tigh layout to adjust padding
plt.tight_layout()

plt.show()

# %%
#calculate growth rate in each year
#growth_rate
import matplotlib.pyplot as plt
import pandas as pd
growth_rate = [(y1[i]-y1[i-1])/y1[i-1]*100 for i in range(1,len(y1))]

#put first number as none
growth_rate.insert(0, None)

#formatting growth rate
fomat_growth_rate = [f"{rate:.2f}%" 
                    if rate is not None 
                    else None
                    for rate in growth_rate]

rate = pd.DataFrame({'years': years, 'GPA_Million': GPA_Million, 'growth_rate': fomat_growth_rate})
print(rate)

#graph with GDP and GDP growth
# Out:
#     years  GPA_Million growth_rate
# 0    1975      $749.13        None
# 1    1976      $790.36       5.50%
# 2    1977      $716.26      -9.38%
# 3    1978      $766.64       7.03%
# 4    1979      $723.74      -5.60%
# 5    1980      $744.38       2.85%
# 6    1981      $815.15       9.51%
# 7    1982      $865.52       6.18%
# 8    1983      $939.29       8.52%
# 9    1984    $1,020.00       8.59%
# 10   1985    $1,100.00       7.84%
# 11   1986    $1,170.00       6.36%
# 12   1987    $1,040.00     -11.11%
# 13   1988    $1,660.00      59.62%
# 14   1989    $1,350.00     -18.67%
# 15   1990    $1,400.00       3.70%
# 16   1991    $2,050.00      46.43%
# 17   1992    $2,490.00      21.46%
# 18   1993    $2,530.00       1.61%
# 19   1994    $2,790.00      10.28%
# 20   1995    $3,440.00      23.30%
# 21   1996    $3,510.00       2.03%
# 22   1997    $3,440.00      -1.99%
# 23   1998    $3,120.00      -9.30%
# 24   1999    $3,520.00      12.82%
# 25   2000    $3,650.00       3.69%
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Example data (from your original input)
years = [1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
GPA_Million = [749.13, 790.36, 716.26, 766.64, 723.74, 744.38, 815.15, 865.52, 939.29, 1020.00, 1100.00, 1170.00, 1040.00, 1660.00, 1350.00, 1400.00, 2050.00, 2490.00, 2530.00, 2790.00, 3440.00, 3510.00, 3440.00, 3120.00, 3520.00, 3650.00, 3980.00, 4280.00, 4660.00, 5340.00, 6290.00, 7270.00, 8640.00, 10350.00, 10400.00, 11240.00, 12830.00, 14050.00, 15230.00, 16700.00, 18050.00, 20020.00, 22180.00, 24570.00, 27090.00, 25870.00, 26960.00, 29500.00, 31770.00]

# Calculate growth rate
growth_rate = [(GPA_Million[i] - GPA_Million[i-1]) / GPA_Million[i-1] * 100 for i in range(1, len(GPA_Million))]
growth_rate.insert(0, None)  # Insert None for the first year

# Format the growth rate
fomat_growth_rate = [f"{rate:.2f}%" if rate is not None else None for rate in growth_rate]

# Create DataFrame
rate = pd.DataFrame({'years': years, 'GPA_Million': GPA_Million, 'growth_rate': fomat_growth_rate})

# Plot GDP and growth rate on the same graph
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot GDP
ax1.set_xlabel('Year')
ax1.set_ylabel('GDP in Million $', color='tab:blue')
ax1.plot(rate['years'], rate['GPA_Million'], marker='o', linestyle='-', color='tab:blue', label="GDP in Million $")
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.legend(loc = 0)

# Create a second y-axis to plot growth rate
ax2 = ax1.twinx()
ax2.set_ylabel('Growth Rate (%)', color='tab:green')
ax2.plot(rate['years'], growth_rate, marker='x', linestyle='-', color='tab:green', label="Growth Rate (%)")
ax2.tick_params(axis='y', labelcolor='tab:green')
ax2.legend(loc = 9)

# Title and layout
plt.title('Economic Growth: GDP and Growth Rate')
fig.tight_layout()

# Show plot
plt.show()

# %%
#sectors that contributes
Sectors = pd.read_excel("Sectors Contributed.xlsx")
#format_sectors = [""]
S = pd.DataFrame["Year: "]
print(Sectors)
# Out:
#     sectors  Agriculture   Industry  Service   other
# 0      2012        0.3352    0.2298   0.3352  0.0998
# 1      2013        0.3160    0.2407   0.3861  0.0572
# 2      2014        0.2887    0.2561   0.3970  0.0582
# 3      2015        0.2658    0.2768   0.3983  0.0591
# 4      2016        0.2474    0.2945   0.3989  0.0592
# 5      2017        0.2336    0.3085   0.3972  0.0607
# 6      2018        0.2201    0.3229   0.3949  0.0621
# 7      2019        0.2071    0.3423   0.3885  0.0621
# 8      2020        0.2270    0.3456   0.3660  0.0614
# 9      2021        0.2285    0.3683   0.3418  0.0614
# 10     2022        0.2223    0.3790   0.3385  0.0602
# 11     2023        0.2530    0.3280   0.4190  0.0000

# %%
#do model and make skewness

# %%
#country that invest

# %%
#graph using power BI

# %%
GPA_Million = GPA_Million.replace(r'[\$,]', '', regex=True).astype(float)
mean = np.mean(GPA_Million)
print('mean: ',mean)

median=np.median(GPA_Million)
median


mode=stats.mode(GPA_Million)
print('mode:',mode)

std=np.std(GPA_Million)
print('standard deviation:',std)

variance=np.var(GPA_Million)
print('variance:',variance)

range = np.max(GPA_Million) - np.min(GPA_Million)
range

maximum=np.max(GPA_Million)
maximum

minimum=np.min(GPA_Million)
minimum

sum=np.sum(GPA_Million)
sum

count=len(GPA_Million)
count

sem = stats.sem(GPA_Million)
confidence_level = 0.95 
confidence_interval = stats.t.interval(confidence_level, len(GPA_Million) - 1, loc=mean,scale=sem)
confidence_interval
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 GPA_Million = GPA_Million.replace(r'[\$,]', '', regex=True).astype(float)
#       2 mean = np.mean(GPA_Million)
#       3 print('mean: ',mean)
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
skewness = skew(GPA_Million)
skewness
# Out:
# np.float64(1.1943043248312528)

# %%
kurtosis=kurtosis(GPA_Million)
print(kurtosis)
# Out:
# 0.10197517986987492
